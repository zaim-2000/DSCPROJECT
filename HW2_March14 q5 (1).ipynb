# %% [markdown]
# ### Home Work #2 (100 marks)
# **Due on March 14**
# Group Members Names
#
# 1)
# 2)

# %% [markdown]
# **1) Indexing (20 marks)**
# 1) read GDP data from "https://raw.githubusercontent.com/datasets/gdp/master/data/gdp.csv"
# 2) rename the appropriate column to "GDP"
# 3) have data only for 2 countries of your choice and from 2020 onwards only using booliean filtering
# 5) set both country and year as index for the original datafram (not the selection ones)
# 6) repeat 3 using exactly for 2020 and 2023
# 7) repeat 3 but for 3 countries of your choice and from 2020 to 2023 (range). Hint use pd.IndexSlice

# %%
gdp = pd.read_csv("https://raw.githubusercontent.com/datasets/gdp/master/data/gdp.csv")
print(gdp.head())

# %% [markdown]
# ***2) Cleaning Data and Groupby (20 marks)***
#
# 1. Read titanic data from https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
# 2. Check the number of missing values for the columns
# 3. Fill missing Age values with median age and Fill missing Embarked with the most frequent port (note need to use mode()[0] as mode() -
# 4. Returns a series) and drop cabin column
# 5. Calculate average age of passengers by Pclass (1st, 2nd, 3rd class) and round to 2 decimal points
# 6. Calculate survival rate by Sex

# %%
url_t = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
titan = pd.read_csv(url_t)
titan.head()

# %% [markdown]
# ***3) Seaborn Plot (20 marks)***
#
# 1) download `tips` data from seaborn
# 2) Draw a plot with spliting the data based on `time` and `smoking status`. Use `sex` for color and `size` for size
# 3) For the above `titanic data`, plot a histogram of `Age` for survived vs not survived passengers (use `hue`). Also add `kde` (kernal density estimate) or probability density. you may stack the two histograms.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load Seaboen's built-in example dataset
tips = sns.load_dataset("tips")
tips.head()

# %% [markdown]
# **4) Merge (20 marks)**
# 1) read GDP data from "https://raw.githubusercontent.com/datasets/gdp/master/data/gdp.csv"
# 2) read population data from "https://raw.githubusercontent.com/datasets/population/master/data/population.csv"
# 3) Change "Year" from both data to numeric value.
# 4) Rename the columns as appropriate.
# 5) Have population data only for 2020 onwards
# 6) inner merge these two data with apprpriate common ids

# %% [markdown]
# ***5) Time Series (20 marks)***
#
# 1) install yfinance (pip install yfinance) and then import
# 2) download the data as: df = yf.download("AAPL", start="2021-01-01", end="2023-12-31")
# 3) use df_aapl['Close'].plot() to plot time series. Give a suitable title and ylabel
# 4) plot 7 day and 30 day moving averages of `close` value and plot. Add title, xlabel, ylabel and legend

# %%
# %pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: yfinance in /home/jupyter-xuan7722/.local/lib/python3.10/site-packages (1.2.0)
# Requirement already satisfied: pandas>=1.3.0 in /opt/tljh/user/lib/python3.10/site-packages (from yfinance) (2.1.1)
# Requirement already satisfied: numpy>=1.16.5 in /opt/tljh/user/lib/python3.10/site-packages (from yfinance) (1.26.0)
# Requirement already satisfied: requests>=2.31 in /opt/tljh/user/lib/python3.10/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /home/jupyter-xuan7722/.local/lib/python3.10/site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/tljh/user/lib/python3.10/site-packages (from yfinance) (3.11.0)
# Requirement already satisfied: pytz>=2022.5 in /opt/tljh/user/lib/python3.10/site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in /home/jupyter-xuan7722/.local/lib/python3.10/site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /home/jupyter-xuan7722/.local/lib/python3.10/site-packages (from yfinance) (4.0.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/tljh/user/lib/python3.10/site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in /home/jupyter-xuan7722/.local/lib/python3.10/site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /home/jupyter-xuan7722/.local/lib/python3.10/site-packages (from yfinance) (7.34.0)
# Requirement already satisfied: websockets>=13.0 in /home/jupyter-xuan7722/.local/lib/python3.10/site-packages (from yfinance) (16.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/tljh/user/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in /opt/tljh/user/lib/python3.10/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (1.15.1)
# Requirement already satisfied: certifi>=2024.2.2 in /home/jupyter-xuan7722/.local/lib/python3.10/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2026.2.25)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/tljh/user/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /opt/tljh/user/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/tljh/user/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/tljh/user/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/tljh/user/lib/python3.10/site-packages (from requests>=2.31->yfinance) (1.26.15)
# Requirement already satisfied: pycparser in /opt/tljh/user/lib/python3.10/site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (2.21)
# Requirement already satisfied: six>=1.5 in /opt/tljh/user/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# WARNING: Error parsing requirements for fit-plot: [Errno 13] Permission denied: '/opt/tljh/user/lib/python3.10/site-packages/fit_plot-0.1.15.dist-info/METADATA'
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# Download Apple stock data from 2021-01-01 to 2023-12-31
df_aapl = yf.download("AAPL", start="2021-01-01", end="2023-12-31")
print(df_aapl.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2021-01-04  125.856712  129.941387  123.279474  129.853862  143301900
# 2021-01-05  127.412773  128.122740  124.903612  125.350988   97664900
# 2021-01-06  123.123856  127.451673  122.909895  124.213106  155088000
# 2021-01-07  127.325233  128.015745  124.349256  124.835528  109578200
# 2021-01-08  128.424194  128.988271  126.654160  128.793750  105158200

# %%
# Plot the daily closing price of Apple stock over time
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))

df_aapl['Close'].plot()

plt.title("AAPL Closing Price (2021–2023)")
plt.xlabel("Date")
plt.ylabel("Closing Price (USD)")

plt.show()

# %%
# Calculate the 7-day and 30-day moving averages of the closing price
# Moving averages help smooth short-term fluctuations in stock prices
df_aapl['MA7'] = df_aapl[('Close','AAPL')].rolling(window=7).mean()
df_aapl['MA30'] = df_aapl[('Close','AAPL')].rolling(window=30).mean()

# %%
# Plot the closing price together with the 7-day and 30-day moving averages
plt.figure(figsize=(12,6))

plt.plot(df_aapl.index, df_aapl[('Close','AAPL')], label='Close Price')
plt.plot(df_aapl.index, df_aapl['MA7'], label='7-Day Moving Average')
plt.plot(df_aapl.index, df_aapl['MA30'], label='30-Day Moving Average')

plt.title("AAPL Closing Price with 7-Day and 30-Day Moving Averages")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()

plt.show()

# %%
# check the Colums
df_aapl.columns
# Out:
# MultiIndex([( 'Close', 'AAPL'),
#             (  'High', 'AAPL'),
#             (   'Low', 'AAPL'),
#             (  'Open', 'AAPL'),
#             ('Volume', 'AAPL'),
#             (   'MA7',     ''),
#             (  'MA30',     '')],
#            names=['Price', 'Ticker'])
